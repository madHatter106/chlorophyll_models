# %%
import pathlib
import pickle

import seaborn as sb
import pandas as pd
import numpy as np
import pymc3 as pm
from cmocean import cm
import theano.tensor as tt
import matplotlib.pyplot as pl
from matplotlib import rcParams
# Out:
# /accounts/ekarakoy/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
% matplotlib inline

# %%
pl.style.use('fivethirtyeight')
rcParams['axes.labelsize'] = 16
rcParams['xtick.labelsize'] = 16
rcParams['ytick.labelsize'] = 16
rcParams['legend.fontsize'] = 16

# %%
home = pathlib.Path.home()
fs = home / 'DEV-ALL/Bayesian_Chl_Algorithms/pickleJar/NOMAD_AOP&IOPs.pkl'
with open(fs, 'rb') as f:
    datadict = pickle.load(f)
    d_aop = datadict['d_aop_imputed_rrs']

# %%
d_aop.describe().T
# Out:
#                count         mean          std          min          25%  \
# doy           4459.0   162.926551   107.284396     2.850000    60.016667
# lat           4459.0     1.868658    44.765125   -77.035600   -61.299000
# lon           4459.0   -61.592062    53.894958  -179.955000   -82.699950
# etopo2        4459.0  1312.346715  1766.435289     0.000000    18.000000
# bathymetry    4459.0 -1335.069348  1754.667531 -7747.304199 -2801.958008
# oisst         4459.0    14.841534    10.374969    -1.800000     1.860000
# wtemp         1235.0    18.021513     8.203662    -1.880000    13.425000
# woa_sst_mean  2516.0    16.346622     9.908297    -1.459301     9.008673
# woa_sst_se    2516.0     0.038228     0.025942     0.008451     0.018678
# sal            672.0    28.717463     8.397708     0.080000    24.885000
# woa_sal_mean  2511.0    34.751382     1.254071    27.280552    33.529337
# woa_sal_se    2511.0     0.018470     0.018210     0.002964     0.006720
# rrs411        4293.0     0.004881     0.003447     0.000051     0.002509
# rrs443        4456.0     0.004652     0.003002     0.000190     0.002617
# rrs489        4422.0     0.004590     0.002768     0.000284     0.003051
# rrs510        4207.0     0.003878     0.002901     0.000261     0.002638
# rrs555        4453.0     0.003170     0.003681     0.000183     0.001551
# rrs670        3905.0     0.000762     0.001676     0.000000     0.000100
# fluo_chl      3392.0     2.703251     5.611762     0.012000     0.274000
# hplc_chl      1381.0     2.285293     5.752391     0.017000     0.145000
# is_hplc       4127.0     0.334626     0.471917     0.000000     0.000000
# chl           4127.0     2.680228     5.758436     0.012000     0.233325
#
#                      50%          75%          max
# doy           154.225000   262.229167   365.450000
# lat            27.093000    34.458500    79.690000
# lon           -67.675000   -63.961500   179.907000
# etopo2        240.000000  2789.500000  7978.000000
# bathymetry   -321.559998   -46.526001   634.359985
# oisst          16.380000    24.430000    30.890000
# wtemp          18.090000    24.441000    36.250000
# woa_sst_mean   17.161522    25.505406    29.414753
# woa_sst_se      0.029443     0.051658     0.174434
# sal            33.250000    33.630000    37.010000
# woa_sal_mean   34.483055    35.831049    38.609764
# woa_sal_se      0.013949     0.026861     0.276933
# rrs411          0.003984     0.006301     0.030600
# rrs443          0.003899     0.006076     0.036769
# rrs489          0.004153     0.005655     0.063814
# rrs510          0.003272     0.004027     0.077740
# rrs555          0.002004     0.003135     0.108867
# rrs670          0.000200     0.000571     0.027700
# fluo_chl        0.830000     2.240080    77.864800
# hplc_chl        0.538000     1.694000    70.213300
# is_hplc         0.000000     1.000000     1.000000
# chl             0.764000     2.150000    77.864800

# %%
d_aop.head().T
# Out:
#                                 0                    1                    2  \
# id                           1565                 1566                 1567
# datetime      2003-04-15 15:15:00  2003-04-15 16:50:00  2003-04-15 17:50:00
# doy                       105.875                106.5              106.542
# lat                       38.4279               38.368              38.3074
# lon                        -76.61                -76.5               -76.44
# etopo2                          0                    0                    1
# bathymetry                 -3.044               -10.44               -8.956
# oisst                         3.7                  3.7                  3.7
# wtemp                         NaN                  NaN                  NaN
# woa_sst_mean                  NaN                  NaN                  NaN
# woa_sst_se                    NaN                  NaN                  NaN
# sal                           NaN                  NaN                  NaN
# woa_sal_mean                  NaN                  NaN                  NaN
# woa_sal_se                    NaN                  NaN                  NaN
# rrs411                  0.0012044           0.00106171          0.000971132
# rrs443                 0.00168608           0.00138402           0.00118548
# rrs489                 0.00329309           0.00217292            0.0018432
# rrs510                 0.00403634           0.00249924           0.00228772
# rrs555                 0.00747919           0.00415208           0.00424561
# rrs670                 0.00346456           0.00169488           0.00161228
# fluo_chl                    38.19                35.01                26.91
# hplc_chl                      NaN                  NaN                  NaN
# is_hplc                         0                    0                    0
# chl                         38.19                35.01                26.91
#
#                                 3                    4
# id                           1568                 1559
# datetime      2003-04-17 18:15:00  2003-07-21 18:27:00
# doy                           108                203.2
# lat                       38.6367              38.3047
# lon                        -76.32               -76.44
# etopo2                          3                    1
# bathymetry                -10.008               -9.118
# oisst                         3.7                22.03
# wtemp                         NaN                  NaN
# woa_sst_mean                  NaN                  NaN
# woa_sst_se                    NaN                  NaN
# sal                           NaN                  NaN
# woa_sal_mean                  NaN                  NaN
# woa_sal_se                    NaN                  NaN
# rrs411                  0.0014718          0.000905091
# rrs443                 0.00174123           0.00102233
# rrs489                 0.00287731           0.00150593
# rrs510                 0.00366425           0.00190341
# rrs555                  0.0069817           0.00280069
# rrs670                 0.00323384           0.00179052
# fluo_chl                    47.96                23.55
# hplc_chl                      NaN                  NaN
# is_hplc                         0                    0
# chl                         47.96                23.55

# %% [markdown]
# Take a subset of data corresponding to SWF bands, take the log of the bands, then try the following models:
# * Rd2Bl
# * MxBl2Rd
# * Rd2MxBl
# * MxBl2Gr

# %%
def compute_predictors(df):
    '''function to compute ratios mentioned above'''
    
    ins = df.shape[1]-2
    df.insert(ins, 'maxBlue', df.loc[:, ['rrs443', 'rrs489', 'rrs510']].max(axis=1))
    df.insert(ins, 'Rd2Bl', df.rrs670 / df.rrs411)
    df.insert(ins, 'mxBlu2Rd', df.maxBlue / df.rrs670)
    df.insert(ins, 'Rd2MxBlu', df.rrs670 / df.maxBlue)
    df.insert(ins, 'mxBlu2Gr', df.maxBlue / df.rrs555)

# %%
d = d_aop[['id','rrs411', 'rrs443', 'rrs489', 'rrs510' ,'rrs555', 'rrs670',
        'etopo2', 'oisst', 'chl']]

# %%
d.etopo2 += 1e-6
# Out:
# /accounts/ekarakoy/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
d.rrs670 += 1e-6
# Out:
# /accounts/ekarakoy/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
compute_predictors(d)

# %%
d.head().T
# Out:
#                  0           1            2           3            4
# id            1565        1566         1567        1568         1559
# rrs411   0.0012044  0.00106171  0.000971132   0.0014718  0.000905091
# rrs443  0.00168608  0.00138402   0.00118548  0.00174123   0.00102233
# rrs489  0.00329309  0.00217292    0.0018432  0.00287731   0.00150593
# rrs510  0.00403634  0.00249924   0.00228772  0.00366425   0.00190341
# rrs555  0.00747919  0.00415208   0.00424561   0.0069817   0.00280069
# rrs670  0.00346556  0.00169588   0.00161328  0.00323484   0.00179152
# etopo2       1e-06       1e-06            1           3            1
# oisst          3.7         3.7          3.7         3.7        22.03
# chl          38.19       35.01        26.91       47.96        23.55

# %%
d.describe().T
# Out:
#            count         mean          std       min        25%         50%  \
# rrs411    4293.0     0.004881     0.003447  0.000051   0.002509    0.003984
# rrs443    4456.0     0.004652     0.003002  0.000190   0.002617    0.003899
# rrs489    4422.0     0.004590     0.002768  0.000284   0.003051    0.004153
# rrs510    4207.0     0.003878     0.002901  0.000261   0.002638    0.003272
# rrs555    4453.0     0.003170     0.003681  0.000183   0.001551    0.002004
# rrs670    3905.0     0.000763     0.001676  0.000001   0.000101    0.000201
# etopo2    4459.0  1312.346716  1766.435289  0.000001  18.000001  240.000001
# mxBlu2Gr  4453.0     2.469665     1.953052  0.399575   1.026430    1.752781
# Rd2MxBlu  3905.0     0.151491     0.228460  0.000067   0.018366    0.051441
# mxBlu2Rd  3905.0   195.219074  1111.539374  0.367462   5.684364   19.439881
# Rd2Bl     3743.0     0.326713     0.964018  0.000088   0.017560    0.056570
# maxBlue   4459.0     0.005289     0.003396  0.000284   0.003149    0.004429
# oisst     4459.0    14.841534    10.374969 -1.800000   1.860000   16.380000
# chl       4127.0     2.680228     5.758436  0.012000   0.233325    0.764000
#
#                   75%           max
# rrs411       0.006301      0.030600
# rrs443       0.006076      0.036769
# rrs489       0.005655      0.063814
# rrs510       0.004027      0.077740
# rrs555       0.003135      0.108867
# rrs670       0.000572      0.027701
# etopo2    2789.500001   7978.000001
# mxBlu2Gr     3.313311     12.013536
# Rd2MxBlu     0.175921      2.721368
# mxBlu2Rd    54.448164  14876.431585
# Rd2Bl        0.248207     31.870547
# maxBlue      0.006617      0.077740
# oisst       24.430000     30.890000
# chl          2.150000     77.864800

# %%
_, ax = pl.subplots(figsize=(12,12))
sb.heatmap(d.iloc[:, 1:].corr(), vmin=-1, vmax=1, annot=True,
          cmap=cm.balance_r);

# %%
d2 = d.copy()
d2.loc[d2.etopo2==0, 'etopo2'] = 1e-6
d2.iloc[:, 1:] = np.log10(d2.iloc[:, 1:])
_, ax = pl.subplots(figsize=(12,12))
sb.heatmap(d2.iloc[:, 1:].corr(), vmin=-1, vmax=1, annot=True,
          cmap=cm.balance_r);

# %%
d2.describe().T
# Out:
#            count      mean       std       min       25%       50%       75%  \
# rrs411    4293.0 -2.419273  0.326394 -4.290672 -2.600448 -2.399659 -2.200602
# rrs443    4456.0 -2.421040  0.292499 -3.721171 -2.582159 -2.409061 -2.216361
# rrs489    4422.0 -2.395443  0.224659 -3.546531 -2.515600 -2.381635 -2.247581
# rrs510    4207.0 -2.471649  0.213284 -3.583095 -2.578727 -2.485250 -2.395018
# rrs555    4453.0 -2.622084  0.288982 -3.737064 -2.809368 -2.698108 -2.503705
# rrs670    3905.0 -3.618952  0.675496 -6.000000 -3.996124 -3.696387 -3.242875
# etopo2    4459.0  1.987770  1.981375 -6.000000  1.255273  2.380211  3.445526
# mxBlu2Gr  4453.0  0.274327  0.317070 -0.398402  0.011329  0.243728  0.520262
# Rd2MxBlu  3905.0 -1.277415  0.727052 -4.172499 -1.735983 -1.288694 -0.754682
# mxBlu2Rd  3905.0  1.277415  0.727052 -0.434787  0.754682  1.288694  1.735983
# Rd2Bl     3743.0 -1.169456  0.809664 -4.056919 -1.755482 -1.247411 -0.605186
# maxBlue   4459.0 -2.347405  0.251105 -3.546531 -2.501827 -2.353721 -2.179358
# oisst     4249.0  0.953024  0.615909 -2.000000  0.640481  1.231470  1.392521
# chl       4127.0 -0.112459  0.687956 -1.920819 -0.632039 -0.116907  0.332438
#
#                max
# rrs411   -1.514280
# rrs443   -1.434521
# rrs489   -1.195083
# rrs510   -1.109354
# rrs555   -0.963104
# rrs670   -1.557505
# etopo2    3.901894
# mxBlu2Gr  1.079671
# Rd2MxBlu  0.434787
# mxBlu2Rd  4.172499
# Rd2Bl     1.503390
# maxBlue  -1.109354
# oisst     1.489818
# chl       1.891341

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 15 columns):
# id          4459 non-null object
# rrs411      4293 non-null float64
# rrs443      4456 non-null float64
# rrs489      4422 non-null float64
# rrs510      4207 non-null float64
# rrs555      4453 non-null float64
# rrs670      3905 non-null float64
# etopo2      4459 non-null float64
# mxBlu2Gr    4453 non-null float64
# Rd2MxBlu    3905 non-null float64
# mxBlu2Rd    3905 non-null float64
# Rd2Bl       3743 non-null float64
# maxBlue     4459 non-null float64
# oisst       4249 non-null float64
# chl         4127 non-null float64
# dtypes: float64(14), object(1)
# memory usage: 522.6+ KB

# %%
sb.pairplot(d2[['rrs443', 'rrs555', 'rrs670',
               'mxBlu2Gr', 'Rd2MxBlu', 'Rd2Bl',
                'oisst', 'etopo2', 'chl']].dropna(),size=5)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
d3 = d[['id'] + [col for col in d.columns if 'rrs' in col] + ['etopo2', 'oisst', 'chl']]
d3.iloc[:, 1:] = np.log10(d3.iloc[:, 1:])
# Out:
# /accounts/ekarakoy/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
d.loc[d.etopo2==0, 'etopo2'] = 1e-6
d.head()
# Out:
# /accounts/ekarakoy/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /accounts/ekarakoy/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      rrs411    rrs443    rrs489    rrs510    rrs555    rrs670    chl  \
# 0  0.001204  0.001686  0.003293  0.004036  0.007479  0.003465  38.19
# 1  0.001062  0.001384  0.002173  0.002499  0.004152  0.001695  35.01
# 2  0.000971  0.001185  0.001843  0.002288  0.004246  0.001612  26.91
# 3  0.001472  0.001741  0.002877  0.003664  0.006982  0.003234  47.96
# 4  0.000905  0.001022  0.001506  0.001903  0.002801  0.001791  23.55
#
#      etopo2  oisst
# 0  0.000001   3.70
# 1  0.000001   3.70
# 2  1.000000   3.70
# 3  3.000000   3.70
# 4  1.000000  22.03

# %%
d_log.head()
# Out:
#      rrs411    rrs443    rrs489    rrs510    rrs555    rrs670       chl  \
# 0 -6.721774 -6.385349 -5.715930 -5.512417 -4.895630 -5.665171  3.642574
# 1 -6.847877 -6.582762 -6.131683 -5.991767 -5.484146 -6.380146  3.555634
# 2 -6.937048 -6.737605 -6.296251 -6.080199 -5.461870 -6.430107  3.292498
# 3 -6.521267 -6.353163 -5.850900 -5.609131 -4.964462 -5.734086  3.870367
# 4 -7.007475 -6.885672 -6.498347 -6.264109 -5.877890 -6.325246  3.159126
#
#      etopo2     oisst
# 0      -inf  1.308333
# 1      -inf  1.308333
# 2  0.000000  1.308333
# 3  1.098612  1.308333
# 4  0.000000  3.092405

# %%
d.describe().T
# Out:
#          count         mean          std       min        25%         50%  \
# rrs411  4293.0     0.004881     0.003447  0.000051   0.002509    0.003984
# rrs443  4456.0     0.004652     0.003002  0.000190   0.002617    0.003899
# rrs489  4422.0     0.004590     0.002768  0.000284   0.003051    0.004153
# rrs510  4207.0     0.003878     0.002901  0.000261   0.002638    0.003272
# rrs555  4453.0     0.003170     0.003681  0.000183   0.001551    0.002004
# rrs670  3905.0     0.000762     0.001676  0.000000   0.000100    0.000200
# chl     4127.0     2.680228     5.758436  0.012000   0.233325    0.764000
# etopo2  4459.0  1312.346715  1766.435289  0.000000  18.000000  240.000000
# oisst   4459.0    14.841534    10.374969 -1.800000   1.860000   16.380000
#
#                 75%          max
# rrs411     0.006301     0.030600
# rrs443     0.006076     0.036769
# rrs489     0.005655     0.063814
# rrs510     0.004027     0.077740
# rrs555     0.003135     0.108867
# rrs670     0.000571     0.027700
# chl        2.150000    77.864800
# etopo2  2789.500000  7978.000000
# oisst     24.430000    30.890000

# %%
_, ax = pl.subplots(figsize=(7, 7))
sb.heatmap(d.corr(), vmin=-1, vmax=1, ax=ax, annot=True,
          mask=np.triu(np.ones([d.shape[1]])), cmap=cm.balance_r);

# %% [markdown]
# <u>References</u>
#
# 1 - dynamic biogeo
#
# 2 - importance of sst:  Brander, K. (2009), Impacts of climate change on marine ecosystems and fisheries, J. Mar. Biol. Ass. India, 51, 1–13.
